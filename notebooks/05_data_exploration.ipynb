# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdelt = pd.read_parquet('../cache/gdelt_cleaned.parquet')

# %%
gdelt.Date.hist(bins=100)
plt.xlim([pd.Timestamp('2019-01-01'), pd.Timestamp('2024-01-01')])
plt.grid(True, alpha=0.3)
plt.xlabel('Date')
plt.ylabel('Number of events')
plt.title('Distribution of events in GDELT data by date')
plt.show()

# %% [markdown]
# We can see that the number of events in the database decreases slightly over time but not significantly. There are no major gaps in the data.

# %%
# avg number of articles per event over time
gdelt.groupby(gdelt['Date'].dt.to_period('M'))['NumArticles'].mean().plot()
plt.ylim([0, 25])
plt.title('Average number of articles per event over time')
plt.xlabel('Date')
plt.ylabel('Avg articles per event')
plt.tight_layout()

# %% [markdown]
# The average number of articles per event is relatively stable over time.

# %%
gdelt.QuadClass.hist()
plt.title('Distribution of event types in general')
plt.tight_layout()
plt.show()

# %%
gdelt.Actor1TypeGeneral.hist()
plt.title('Distribution of general actor types for Actor1')
plt.tight_layout()
plt.show()

# %%
gdelt.Actor2TypeGeneral.hist()
plt.title('Distribution of general actor types for Actor2')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Actor1TypeGeneral', y='GoldsteinScale', data=gdelt, order=['GOV', 'Opposition', 'Business', 'Benevolent', 'Other'])
plt.title('Potential impact on country stability by initiating type')
plt.tight_layout()
plt.show()

# %%
gdelt.columns
# Out:
# Index(['Date', 'Timestamp', 'Actor1Country', 'Actor1GeoCountry', 'Actor1Type',
#        'Actor1TypeGeneral', 'Actor2Country', 'Actor2GeoCountry', 'Actor2Type',
#        'Actor2TypeGeneral', 'ActionCountry', 'EventType', 'QuadClass',
#        'GoldsteinScale', 'NumSources', 'NumArticles', 'AvgTone', 'Source'],
#       dtype='object')

# %%
def calc_reaction_magnitude(row):
    return round((row['NumArticles'] + 10 * row['NumSources'] + 20 * abs(row['AvgTone'])) / 20, 2)

# %%
gdelt['Magnitude'] = gdelt.apply(calc_reaction_magnitude, axis=1)
gdelt['Impact'] = gdelt['GoldsteinScale'] * gdelt['Magnitude']

# %%
from funcs.advanced_describe import advanced_describe
advanced_describe(gdelt, drop_cols=['Date', 'Timestamp', 'Source'])
# Out:
#                   present unique         top   share       mean        min  \
# Actor1Country         44%     21       Other  13.97%        NaN        NaN
# Actor1GeoCountry      83%     21       Other  26.21%        NaN        NaN
# Actor1Type            52%     32         GOV  16.47%        NaN        NaN
# Actor1TypeGeneral     52%      5         GOV  30.61%        NaN        NaN
# Actor2Country         32%     21       Other  10.58%        NaN        NaN
# Actor2GeoCountry      58%     21       Other  18.63%        NaN        NaN
# Actor2Type            35%     32         GOV  10.15%        NaN        NaN
# Actor2TypeGeneral     35%      5         GOV  18.81%        NaN        NaN
# ActionCountry         94%     21       Other  29.85%        NaN        NaN
# EventType            100%     20     Consult  24.50%        NaN        NaN
# QuadClass            100%      4  VerbalCoop  60.38%        NaN        NaN
# GoldsteinScale       100%    NaN         NaN    None   0.502059      -10.0
# NumSources           100%    NaN         NaN    None   2.297014        1.0
# NumArticles          100%    NaN         NaN    None  21.517894       11.0
# AvgTone              100%    NaN         NaN    None   -2.15403 -38.709677
# Magnitude            100%    NaN         NaN    None   5.644157       1.05
# Impact               100%    NaN         NaN    None  -1.193612     -424.6
#
#                         50%        max
# Actor1Country           NaN        NaN
# Actor1GeoCountry        NaN        NaN
# Actor1Type              NaN        NaN
# Actor1TypeGeneral       NaN        NaN
# Actor2Country           NaN        NaN
# Actor2GeoCountry        NaN        NaN
# Actor2Type              NaN        NaN
# Actor2TypeGeneral       NaN        NaN
# ActionCountry           NaN        NaN
# EventType               NaN        NaN
# QuadClass               NaN        NaN
# GoldsteinScale          1.0       10.0
# NumSources              2.0       58.0
# NumArticles            20.0     2040.0
# AvgTone           -1.948052  26.315789
# Magnitude              4.88     103.98
# Impact                 5.37    662.596
